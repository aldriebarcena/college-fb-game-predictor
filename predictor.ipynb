# %%
import pandas as pd
from sklearn.ensemble import RandomForestClassifier # ML model that picks up NON-LINEARITIES in data
from sklearn.metrics import precision_score # metrics to test precision

# %%
matches = pd.read_csv("matches.csv", index_col = 0) # reading matches.csv

# creating columns of wanted predictors
matches["date"] = pd.to_datetime(matches["date"])
matches["venue_code"] = matches["home/away"].astype("category").cat.codes # creating venue codes for 0 (home) -1 (away)
matches["opp_code"] = matches["opponent"].astype("category").cat.codes # same thing with opponent column
matches["hour"] = matches["time"].str.replace(r':.*[AP]M', '', regex=True).astype("int")
matches["day_code"] = matches["date"].dt.dayofweek
matches["target"] = (matches["w/l"] == "W").astype("int") # creates target for model to look for

# list of initial predictors
predictors = ["venue_code", "opp_code", "hour", "day_code", "target"]

# %%
rf = RandomForestClassifier(n_estimators=50, min_samples_split = 10, random_state=1)
# random forest has series of decision trees
# each decision trees has different parameters
# higher n_estimators -> longer algorithm -> more accurate
# min_samples_split: # samples in each leaf, higher -> less likely to overfit -> lower accuracy
# random_state: same result if run multiple times

# %%
# creating rolling averages column
def rolling_averages(group, cols, new_cols):
    group = group.sort_values("date")
    rolling_stats = group[cols].rolling(3, closed='left').mean() # take previous 3 weeks
    group[new_cols] = rolling_stats
    group = group.dropna(subset=new_cols)
    return group

cols = ["yds_passing", "yds_rushing", "yds_tot_off", "pct_passing"]
new_cols = [f"{c}_rolling" for c in cols]

rolling_averages(group, cols, new_cols)
# Out:
#      g       date      time  day          school home/away          opponent  \
# 3    4 2023-09-16   7:00 PM  Sat  San Jose State         @            Toledo
# 4    5 2023-09-22  10:30 PM  Fri  San Jose State       NaN         Air Force
# 5    6 2023-10-07   8:00 PM  Sat  San Jose State         @       Boise State
# 6    7 2023-10-14   6:00 PM  Sat  San Jose State         @        New Mexico
# 7    8 2023-10-21   7:00 PM  Sat  San Jose State       NaN        Utah State
# 8    9 2023-10-29  12:00 AM  Sun  San Jose State         @            Hawaii
# 9   10 2023-11-11  10:30 PM  Sat  San Jose State       NaN      Fresno State
# 10  11 2023-11-18  10:30 PM  Sat  San Jose State       NaN   San Diego State
# 11  12 2023-11-25   3:00 PM  Sat  San Jose State         @  Nevada-Las Vegas
# 12  13 2023-12-23  10:30 PM  Sat  San Jose State         N  Coastal Carolina
#
#         conf w/l  pts  ...            team  venue_code  opp_code hour  \
# 3        MAC   L   17  ...  san jose state           0        54    7
# 4        MWC   L   20  ...  san jose state          -1        14   10
# 5        MWC   L   27  ...  san jose state           0        19    8
# 6        MWC   W   52  ...  san jose state           0        40    6
# 7        MWC   W   42  ...  san jose state          -1        58    7
# 8        MWC   W   35  ...  san jose state           0        28   12
# 9        MWC   W   42  ...  san jose state          -1        26   10
# 10       MWC   W   24  ...  san jose state          -1        48   10
# 11       MWC   W   37  ...  san jose state           0        39    3
# 12  Sun Belt   L   14  ...  san jose state           1        22   10
#
#    day_code  target  yds_passing_rolling  yds_rushing_rolling  \
# 3         5       0           211.666667           173.666667
# 4         4       0           221.666667           121.000000
# 5         5       0           224.000000           140.666667
# 6         5       1           264.000000            86.333333
# 7         5       1           278.666667           159.333333
# 8         6       1           238.666667           204.666667
# 9         5       1           214.000000           242.333333
# 10        5       1           172.000000           260.333333
# 11        5       1           190.333333           237.000000
# 12        5       0           189.666667           242.333333
#
#     yds_tot_off_rolling  pct_passing_rolling
# 3            385.333333            59.500000
# 4            342.666667            61.066667
# 5            364.666667            64.100000
# 6            350.333333            62.533333
# 7            438.000000            58.733333
# 8            443.333333            60.866667
# 9            456.333333            61.200000
# 10           432.333333            62.166667
# 11           427.333333            62.166667
# 12           432.000000            66.033333
#
# [10 rows x 36 columns]

# %%
# create new table with matches_rolling
matches_rolling = matches.groupby("team").apply(lambda x: rolling_averages(x, cols, new_cols),include_groups=False)
matches_rolling = matches_rolling.droplevel('team')
matches_rolling.index = range(matches_rolling.shape[0])

# %%
def make_predictions(data, predictors):
    # training first half of season to be able to predict second half of season
    train = data[data["date"] < '2023-10-24']
    test = data[data["date"] > '2023-10-24']
    rf.fit(train[predictors], train["target"])
    preds = rf.predict(test[predictors])
    precision = precision_score(test["target"], preds)
    return precision

# %%
# make prediction based on original predictors + rolling average
predictors += new_cols
precision = make_predictions(matches_rolling, predictors)

# %%
precision # 100% accuracy
# Out:
# np.float64(1.0)
